# %%
import numpy as np
from astropy.io import fits

# %%
import matplotlib.pyplot as plt

# %%
file11 = fits.open('./obj1/image1.fits')
file21 = fits.open('./obj1/image2.fits')
file31 = fits.open('./obj1/image3.fits')
file41 = fits.open('./obj1/image4.fits')
file51 = fits.open('./obj1/image5.fits')

fig = plt.figure(figsize=(20, 10))

rows = 2
columns = 3

fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(file11[0].data,norm=LogNorm())
plt.axis('off')
plt.title("First")
plt.colorbar()
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(file21[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Second")
plt.colorbar()
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(file31[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Third")
plt.colorbar()
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(file41[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fourth")
plt.colorbar()

# Adds a subplot at the 5th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(file51[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fifth")
plt.colorbar()

# %%
file11[0].data
# Out:
# array([[7233., 4904., 3869., ..., 6323., 5806., 4771.],
#        [4387., 4128., 4128., ..., 5288., 4253., 4253.],
#        [3869., 3611., 3611., ..., 5288., 5288., 4253.],
#        ...,
#        [7226., 6579., 5027., ..., 4208., 4208., 4208.],
#        [4639., 4509., 5027., ..., 4208., 4208., 4208.],
#        [3992., 3474., 3992., ..., 4725., 4208., 3949.]], dtype=float32)

# %%
file11[0].header
# Out:
# SIMPLE  =                    T / Written by SkyView Tue Feb 07 11:45:10 EST 2023
# BITPIX  =                  -32 / 4 byte floating point
# NAXIS   =                    2 / Two dimensional image
# NAXIS1  =                  300 / Width of image
# NAXIS2  =                  300 / Height of image
# CRVAL1  =   245.89675000000003 / Reference longitude
# CRVAL2  =            -26.52575 / Reference latitude
# RADESYS = 'FK5     '           / Coordinate system
# EQUINOX =               2000.0 / Epoch of the equinox
# CTYPE1  = 'RA---TAN'           / Coordinates -- projection
# CTYPE2  = 'DEC--TAN'           / Coordinates -- projection
# CRPIX1  =                150.5 / X reference pixel
# CRPIX2  =                150.5 / Y reference pixel
# CDELT1  = -0.00047222219999999997 / X scale
# CDELT2  = 0.00047222219999999997 / Y scale
# COMMENT
# COMMENT SkyView Survey metadata
# COMMENT
# COMMENT Provenance:  Data taken by ROE and AAO, CalTech, Compression
# ...

# %%
file12 = fits.open('./obj2/skv30028294455129_1.fits')
file22 = fits.open('./obj2/skv30028294455129_2.fits')
file32 = fits.open('./obj2/skv30028294455129_3.fits')
file42 = fits.open('./obj2/skv30028294455129_4.fits')
file52 = fits.open('./obj2/skv30028294455129_5.fits')
file62 = fits.open('./obj2/skv30028294455129_6.fits')

fig = plt.figure(figsize=(20, 10))

rows = 2
columns = 3

fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(file12[0].data,norm=LogNorm())
plt.axis('off')
plt.title("First")
plt.colorbar()
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(file22[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Second")
plt.colorbar()
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(file32[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Third")
plt.colorbar()
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(file42[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fourth")
plt.colorbar()

# Adds a subplot at the 5th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(file52[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fifth")
plt.colorbar()

# Adds a subplot at the 5th position
fig.add_subplot(rows, columns, 6)
  
# showing image
plt.imshow(file62[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fifth")
plt.colorbar()

# %%
file22[0].data
# Out:
# array([[0.00246893, 0.00233762, 0.00249038, ..., 0.00293239, 0.0028843 ,
#         0.00237363],
#        [0.0028033 , 0.00242964, 0.0023992 , ..., 0.00277999, 0.00239239,
#         0.00262998],
#        [0.00269302, 0.00265699, 0.00217222, ..., 0.00231887, 0.00224166,
#         0.00303404],
#        ...,
#        [0.00232649, 0.00221202, 0.00278974, ..., 0.00244028, 0.00242954,
#         0.00258603],
#        [0.00184283, 0.00293697, 0.00311964, ..., 0.00222924, 0.00264846,
#         0.00229553],
#        [0.00260212, 0.00295228, 0.0021513 , ..., 0.0023503 , 0.00238863,
#         0.00227659]], dtype=float32)

# %%
file11[0].header
# Out:
# SIMPLE  =                    T / Written by SkyView Tue Feb 07 11:45:10 EST 2023
# BITPIX  =                  -32 / 4 byte floating point
# NAXIS   =                    2 / Two dimensional image
# NAXIS1  =                  300 / Width of image
# NAXIS2  =                  300 / Height of image
# CRVAL1  =   245.89675000000003 / Reference longitude
# CRVAL2  =            -26.52575 / Reference latitude
# RADESYS = 'FK5     '           / Coordinate system
# EQUINOX =               2000.0 / Epoch of the equinox
# CTYPE1  = 'RA---TAN'           / Coordinates -- projection
# CTYPE2  = 'DEC--TAN'           / Coordinates -- projection
# CRPIX1  =                150.5 / X reference pixel
# CRPIX2  =                150.5 / Y reference pixel
# CDELT1  = -0.00047222219999999997 / X scale
# CDELT2  = 0.00047222219999999997 / Y scale
# COMMENT
# COMMENT SkyView Survey metadata
# COMMENT
# COMMENT Provenance:  Data taken by ROE and AAO, CalTech, Compression
# ...

# %%
file13 = fits.open('./obj3/skv30058168690970_1.fits')
file23 = fits.open('./obj3/skv30058168690970_2.fits')
file33 = fits.open('./obj3/skv30058168690970_3.fits')
file43 = fits.open('./obj3/skv30058168690970_4.fits')
file63 = fits.open('./obj3/skv30058168690970_6.fits')

fig = plt.figure(figsize=(20, 10))

rows = 2
columns = 3

fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(file13[0].data,norm=LogNorm())
plt.axis('off')
plt.title("First")
plt.colorbar()
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(file23[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Second")
plt.colorbar()
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(file33[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Third")
plt.colorbar()
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(file43[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fourth")
plt.colorbar()

# Adds a subplot at the 5th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(file63[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fifth")
plt.colorbar()

# %%
file23[0].data
# Out:
# array([[3841., 3466., 4029., ..., 4090., 3903., 3528.],
#        [4404., 4029., 3466., ..., 3903., 3903., 3903.],
#        [4404., 4029., 3841., ..., 3903., 3903., 3903.],
#        ...,
#        [3771., 3771., 3771., ..., 3955., 3580., 3580.],
#        [3771., 3771., 4146., ..., 3955., 3580., 3580.],
#        [3490., 3865., 3865., ..., 3626., 3626., 4001.]], dtype=float32)

# %%
file23[0].header
# Out:
# SIMPLE  =                    T / Written by SkyView Tue Feb 07 13:48:31 EST 2023
# BITPIX  =                  -32 / 4 byte floating point
# NAXIS   =                    2 / Two dimensional image
# NAXIS1  =                  600 / Width of image
# NAXIS2  =                  600 / Height of image
# CRVAL1  =   204.25382999999994 / Reference longitude
# CRVAL2  =           -29.865761 / Reference latitude
# RADESYS = 'FK5     '           / Coordinate system
# EQUINOX =               2000.0 / Epoch of the equinox
# CTYPE1  = 'RA---TAN'           / Coordinates -- projection
# CTYPE2  = 'DEC--TAN'           / Coordinates -- projection
# CRPIX1  =                300.5 / X reference pixel
# CRPIX2  =                300.5 / Y reference pixel
# CDELT1  = -0.00047222219999999997 / X scale
# CDELT2  = 0.00047222219999999997 / Y scale
# COMMENT
# COMMENT SkyView Survey metadata
# COMMENT
# COMMENT Provenance:  Data taken by ROE and AAO, CalTech, Compression
# ...

# %%
file14 = fits.open('./obj4/image1.fits')
file24 = fits.open('./obj4/image2.fits')
file34 = fits.open('./obj4/image3.fits')
file44 = fits.open('./obj4/image4.fits')
file54 = fits.open('./obj4/image5.fits')


fig = plt.figure(figsize=(20, 10))

rows = 2
columns = 3

fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(file14[0].data,norm=LogNorm())
plt.axis('off')
plt.title("First")
plt.colorbar()
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(file24[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Second")
plt.colorbar()
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(file34[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Third")
plt.colorbar()
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(file44[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fourth")
plt.colorbar()

# Adds a subplot at the 5th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(file54[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fifth")
plt.colorbar()

# %%
file14[0].data
# Out:
# array([[2419., 2180., 2180., ..., 2307., 2307., 2546.],
#        [2299., 2299., 2299., ..., 2307., 2307., 2546.],
#        [2299., 2299., 2299., ..., 2426., 2426., 2396.],
#        ...,
#        [2275., 2275., 2395., ..., 2277., 2157., 2157.],
#        [2275., 2275., 2395., ..., 2396., 2277., 2277.],
#        [2275., 2275., 2395., ..., 2396., 2277., 2277.]], dtype=float32)

# %%
file14[0].header
# Out:
# SIMPLE  =                    T / Written by SkyView Tue Feb 07 11:43:21 EST 2023
# BITPIX  =                  -32 / 4 byte floating point
# NAXIS   =                    2 / Two dimensional image
# NAXIS1  =                  300 / Width of image
# NAXIS2  =                  300 / Height of image
# CRVAL1  =    83.63299999999998 / Reference longitude
# CRVAL2  =   22.013000000000005 / Reference latitude
# RADESYS = 'FK5     '           / Coordinate system
# EQUINOX =               2000.0 / Epoch of the equinox
# CTYPE1  = 'RA---TAN'           / Coordinates -- projection
# CTYPE2  = 'DEC--TAN'           / Coordinates -- projection
# CRPIX1  =                150.5 / X reference pixel
# CRPIX2  =                150.5 / Y reference pixel
# CDELT1  = -0.00047222219999999997 / X scale
# CDELT2  = 0.00047222219999999997 / Y scale
# COMMENT
# COMMENT SkyView Survey metadata
# COMMENT
# COMMENT Provenance:  Data taken by ROE and AAO, CalTech, Compression
# ...

# %%
file15 = fits.open('./obj5/image1.fits')
file25 = fits.open('./obj5/image2.fits')
file35 = fits.open('./obj5/image3.fits')
file45 = fits.open('./obj5/image4.fits')
file55 = fits.open('./obj5/iamge5.fits')


fig = plt.figure(figsize=(20, 10))

rows = 2
columns = 3

fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(file15[0].data,norm=LogNorm())
plt.axis('off')
plt.title("First")
plt.colorbar()
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(file25[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Second")
plt.colorbar()
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(file35[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Third")
plt.colorbar()
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(file45[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fourth")
plt.colorbar()

# Adds a subplot at the 5th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(file55[0].data,norm=LogNorm())
plt.axis('off')
plt.title("Fifth")
plt.colorbar()

# %%
file15[0].data
# Out:
# array([[3116., 3116., 3116., ..., 2588., 2817., 2817.],
#        [3116., 3116., 3116., ..., 3047., 2817., 2817.],
#        [3346., 3346., 3346., ..., 2817., 3506., 2588.],
#        ...,
#        [2419., 2419., 2419., ..., 2672., 2442., 2442.],
#        [2821., 2821., 2591., ..., 2557., 2787., 2787.],
#        [2821., 2821., 2591., ..., 2098., 2328., 2328.]], dtype=float32)

# %%
file15[0].header
# Out:
# SIMPLE  =                    T / Written by SkyView Tue Feb 07 11:47:44 EST 2023
# BITPIX  =                  -32 / 4 byte floating point
# NAXIS   =                    2 / Two dimensional image
# NAXIS1  =                  300 / Width of image
# NAXIS2  =                  300 / Height of image
# CRVAL1  =              274.688 / Reference longitude
# CRVAL2  =              -13.792 / Reference latitude
# RADESYS = 'FK5     '           / Coordinate system
# EQUINOX =               2000.0 / Epoch of the equinox
# CTYPE1  = 'RA---TAN'           / Coordinates -- projection
# CTYPE2  = 'DEC--TAN'           / Coordinates -- projection
# CRPIX1  =                150.5 / X reference pixel
# CRPIX2  =                150.5 / Y reference pixel
# CDELT1  = -0.00047222219999999997 / X scale
# CDELT2  = 0.00047222219999999997 / Y scale
# COMMENT
# COMMENT SkyView Survey metadata
# COMMENT
# COMMENT Provenance:  Data taken by ROE and AAO, CalTech, Compression
# ...
